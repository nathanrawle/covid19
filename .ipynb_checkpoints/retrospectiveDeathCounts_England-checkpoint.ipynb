# %% [markdown]
# # Retrospective Changes in COVID-19 Daily Death Counts in England
# **Investigating how death counts for past dates of death change with each updated release**

# %% [markdown]
# ![img](meteors.png)
#
# *Each dot represents the count for one date of death as reported in a single release. Each vertical line of dots represents all counts for one date of death as reported in consecutive releases. Points form coloured strata to preserve a sense of how the reported counts increase over time.*<br/>
# Find the code for this plot [below](#Meteors)

# %% [markdown]
# ## Key points
# - Deaths from COVID-19 are initially underestimated
# - Through additional releases, the counts approach the final figure over the course of several days
# - The discrepancy was greatest during the latest pandemic 'wave'
# - For parts of the dataset where the data is complete (Aug-Nov):
#     - The largest difference between initially reported count and final count was 328 deaths for 15 November
#     - On average, the difference between smallest and largest reported counts was 112 deaths
#     - On average, it takes 12 days for counts to reach 90-95% of the final figure
#     - On average, counts approach 80-85% of the final figure after 5 days

# %% [markdown]
# ## Navigate
#
# - [Downloading the data](#Downloading-the-releases-from-PHE)
# - [Preparing the data](#Load-data-into-pandas)
# - [Exploring the data](#Exploring-the-data-with-pandas-and-matplotlib)
# - [Charting the discrepancy](#Charting-the-discrepancy)
# - [Approximating time to complete reporting](#How-quickly-do-the-counts-approach-their-'true'-value?)
# - [Accuracy after 'x' days](#Accuracy-of-count-'x'-days-after-first-report)
# - [Other visualisations](#Alternative-visualisations)
#     - [Meteors](#Meteors)
#     - [Dropped straws](#Dropped-straws)
# - [Ideas for further work](#Ideas-for-further-work)

# %% [markdown]
# The data in this document comprise the number of NEW deaths from COVID-19 on EACH day in the period 03-01-2020 to 28-Nov-2020. The data are collected from multiple authorities and reported to Public Health England. PHE makes the data available through daily releases. Each release includes new deaths from the previous day and updated figures for all days prior to that.
#
# Reports of deaths often do not reach PHE on the date they actually occurred. In many cases, it can take a number of days post mortem for a death to be included in a PHE release. This leads to an initial under-reporting of COVID-19 mortality that gradually approaches its true figure over the course of several additional releases.
#
# I wanted to characterise how much the reported number of deaths on a given date changed between initial release and the latest release for that date. I was also interested in exploring how many releases it takes to arrive at the final figure (or a number approaching the final figure, e.g. 50%, 75%, or 95% of the total). In short, I wanted to quantify how the discrepancy between reported and actual deaths changed with respect to time since initial release.

# %% [markdown]
# ## Downloading the releases from PHE

# %%
import requests

# %% [markdown]
# First I needed to retrieve the data I'm interested in. I was able to do this through [PHE's public API](https://coronavirus.data.gov.uk/details/developers-guide). The API allows you to request up to 5 metrics and optionally specify a subregion of the UK. There is also a parameter 'release' that allows you to specify a historic version of the data, i.e. the data as it was published on a specific day in the past. These 'archive' versions of the data are accompanied by the following caveats:

# %% [markdown]
# ![img](caveats.png)

# %% [markdown]
# I only wanted the data for England, and I was only interested in the new deaths within 28 days of a positive test. Since I could only specify one release date per request, a single API query looked like this:

# %%
res = requests.get('https://api.coronavirus.data.gov.uk/v2/data?areaType=nation&areaCode=E92000001&metric=newDeaths28DaysByDeathDate&format=csv&release=2021-01-15')

print(res.text)
# Out:
# date,areaType,areaCode,areaName,newDeaths28DaysByDeathDate
# "2021-01-14",nation,E92000001,England,289
# "2021-01-13",nation,E92000001,England,696
# "2021-01-12",nation,E92000001,England,843
# "2021-01-11",nation,E92000001,England,891
# "2021-01-10",nation,E92000001,England,810
# "2021-01-09",nation,E92000001,England,798
# "2021-01-08",nation,E92000001,England,762
# "2021-01-07",nation,E92000001,England,808
# "2021-01-06",nation,E92000001,England,768
# "2021-01-05",nation,E92000001,England,776
# "2021-01-04",nation,E92000001,England,739
# "2021-01-03",nation,E92000001,England,617
# "2021-01-02",nation,E92000001,England,649
# "2021-01-01",nation,E92000001,England,614
# "2020-12-31",nation,E92000001,England,628
# "2020-12-30",nation,E92000001,England,611
# "2020-12-29",nation,E92000001,England,573
# "2020-12-28",nation,E92000001,England,576
# "2020-12-27",nation,E92000001,England,561
# "2020-12-26",nation,E92000001,England,565
# "2020-12-25",nation,E92000001,England,529
# "2020-12-24",nation,E92000001,England,477
# "2020-12-23",nation,E92000001,England,483
# "2020-12-22",nation,E92000001,England,484
# "2020-12-21",nation,E92000001,England,486
# "2020-12-20",nation,E92000001,England,427
# "2020-12-19",nation,E92000001,England,407
# "2020-12-18",nation,E92000001,England,431
# "2020-12-17",nation,E92000001,England,433
# "2020-12-16",nation,E92000001,England,358
# "2020-12-15",nation,E92000001,England,384
# "2020-12-14",nation,E92000001,England,411
# "2020-12-13",nation,E92000001,England,361
# "2020-12-12",nation,E92000001,England,375
# "2020-12-11",nation,E92000001,England,397
# "2020-12-10",nation,E92000001,England,371
# "2020-12-09",nation,E92000001,England,374
# "2020-12-08",nation,E92000001,England,373
# "2020-12-07",nation,E92000001,England,356
# "2020-12-06",nation,E92000001,England,352
# "2020-12-05",nation,E92000001,England,339
# "2020-12-04",nation,E92000001,England,412
# "2020-12-03",nation,E92000001,England,403
# "2020-12-02",nation,E92000001,England,335
# "2020-12-01",nation,E92000001,England,348
# "2020-11-30",nation,E92000001,England,361
# "2020-11-29",nation,E92000001,England,401
# "2020-11-28",nation,E92000001,England,379
# "2020-11-27",nation,E92000001,England,359
# "2020-11-26",nation,E92000001,England,374
# "2020-11-25",nation,E92000001,England,421
# "2020-11-24",nation,E92000001,England,403
# "2020-11-23",nation,E92000001,England,400
# "2020-11-22",nation,E92000001,England,406
# "2020-11-21",nation,E92000001,England,397
# "2020-11-20",nation,E92000001,England,388
# "2020-11-19",nation,E92000001,England,397
# "2020-11-18",nation,E92000001,England,437
# "2020-11-17",nation,E92000001,England,362
# "2020-11-16",nation,E92000001,England,359
# "2020-11-15",nation,E92000001,England,380
# "2020-11-14",nation,E92000001,England,357
# "2020-11-13",nation,E92000001,England,358
# "2020-11-12",nation,E92000001,England,350
# "2020-11-11",nation,E92000001,England,310
# "2020-11-10",nation,E92000001,England,318
# "2020-11-09",nation,E92000001,England,403
# "2020-11-08",nation,E92000001,England,340
# "2020-11-07",nation,E92000001,England,332
# "2020-11-06",nation,E92000001,England,334
# "2020-11-05",nation,E92000001,England,301
# "2020-11-04",nation,E92000001,England,278
# "2020-11-03",nation,E92000001,England,292
# "2020-11-02",nation,E92000001,England,281
# "2020-11-01",nation,E92000001,England,285
# "2020-10-31",nation,E92000001,England,277
# "2020-10-30",nation,E92000001,England,280
# "2020-10-29",nation,E92000001,England,249
# "2020-10-28",nation,E92000001,England,238
# "2020-10-27",nation,E92000001,England,218
# "2020-10-26",nation,E92000001,England,222
# "2020-10-25",nation,E92000001,England,204
# "2020-10-24",nation,E92000001,England,171
# "2020-10-23",nation,E92000001,England,188
# "2020-10-22",nation,E92000001,England,185
# "2020-10-21",nation,E92000001,England,192
# "2020-10-20",nation,E92000001,England,171
# "2020-10-19",nation,E92000001,England,159
# "2020-10-18",nation,E92000001,England,120
# "2020-10-17",nation,E92000001,England,160
# "2020-10-16",nation,E92000001,England,123
# "2020-10-15",nation,E92000001,England,124
# "2020-10-14",nation,E92000001,England,100
# "2020-10-13",nation,E92000001,England,87
# "2020-10-12",nation,E92000001,England,96
# "2020-10-11",nation,E92000001,England,103
# "2020-10-10",nation,E92000001,England,90
# "2020-10-09",nation,E92000001,England,67
# "2020-10-08",nation,E92000001,England,75
# "2020-10-07",nation,E92000001,England,82
# "2020-10-06",nation,E92000001,England,61
# "2020-10-05",nation,E92000001,England,59
# "2020-10-04",nation,E92000001,England,54
# "2020-10-03",nation,E92000001,England,55
# "2020-10-02",nation,E92000001,England,63
# "2020-10-01",nation,E92000001,England,56
# "2020-09-30",nation,E92000001,England,48
# "2020-09-29",nation,E92000001,England,43
# "2020-09-28",nation,E92000001,England,47
# "2020-09-27",nation,E92000001,England,42
# "2020-09-26",nation,E92000001,England,35
# "2020-09-25",nation,E92000001,England,29
# "2020-09-24",nation,E92000001,England,33
# "2020-09-23",nation,E92000001,England,52
# "2020-09-22",nation,E92000001,England,34
# "2020-09-21",nation,E92000001,England,24
# "2020-09-20",nation,E92000001,England,27
# "2020-09-19",nation,E92000001,England,18
# "2020-09-18",nation,E92000001,England,21
# "2020-09-17",nation,E92000001,England,24
# "2020-09-16",nation,E92000001,England,22
# "2020-09-15",nation,E92000001,England,15
# "2020-09-14",nation,E92000001,England,17
# "2020-09-13",nation,E92000001,England,14
# "2020-09-12",nation,E92000001,England,18
# "2020-09-11",nation,E92000001,England,10
# "2020-09-10",nation,E92000001,England,12
# "2020-09-09",nation,E92000001,England,9
# "2020-09-08",nation,E92000001,England,9
# "2020-09-07",nation,E92000001,England,13
# "2020-09-06",nation,E92000001,England,8
# "2020-09-05",nation,E92000001,England,12
# "2020-09-04",nation,E92000001,England,6
# "2020-09-03",nation,E92000001,England,6
# "2020-09-02",nation,E92000001,England,8
# "2020-09-01",nation,E92000001,England,2
# "2020-08-31",nation,E92000001,England,7
# "2020-08-30",nation,E92000001,England,6
# "2020-08-29",nation,E92000001,England,5
# "2020-08-28",nation,E92000001,England,8
# "2020-08-27",nation,E92000001,England,8
# "2020-08-26",nation,E92000001,England,11
# "2020-08-25",nation,E92000001,England,11
# "2020-08-24",nation,E92000001,England,5
# "2020-08-23",nation,E92000001,England,13
# "2020-08-22",nation,E92000001,England,6
# "2020-08-21",nation,E92000001,England,7
# "2020-08-20",nation,E92000001,England,8
# "2020-08-19",nation,E92000001,England,2
# "2020-08-18",nation,E92000001,England,7
# "2020-08-17",nation,E92000001,England,12
# "2020-08-16",nation,E92000001,England,4
# "2020-08-15",nation,E92000001,England,11
# "2020-08-14",nation,E92000001,England,6
# "2020-08-13",nation,E92000001,England,7
# "2020-08-12",nation,E92000001,England,6
# "2020-08-11",nation,E92000001,England,10
# "2020-08-10",nation,E92000001,England,11
# "2020-08-09",nation,E92000001,England,8
# "2020-08-08",nation,E92000001,England,11
# "2020-08-07",nation,E92000001,England,7
# "2020-08-06",nation,E92000001,England,9
# "2020-08-05",nation,E92000001,England,3
# "2020-08-04",nation,E92000001,England,10
# "2020-08-03",nation,E92000001,England,14
# "2020-08-02",nation,E92000001,England,8
# "2020-08-01",nation,E92000001,England,9
# "2020-07-31",nation,E92000001,England,10
# "2020-07-30",nation,E92000001,England,8
# "2020-07-29",nation,E92000001,England,8
# "2020-07-28",nation,E92000001,England,10
# "2020-07-27",nation,E92000001,England,10
# "2020-07-26",nation,E92000001,England,14
# "2020-07-25",nation,E92000001,England,13
# "2020-07-24",nation,E92000001,England,6
# "2020-07-23",nation,E92000001,England,16
# "2020-07-22",nation,E92000001,England,16
# "2020-07-21",nation,E92000001,England,19
# "2020-07-20",nation,E92000001,England,12
# "2020-07-19",nation,E92000001,England,14
# "2020-07-18",nation,E92000001,England,14
# "2020-07-17",nation,E92000001,England,18
# "2020-07-16",nation,E92000001,England,12
# "2020-07-15",nation,E92000001,England,20
# "2020-07-14",nation,E92000001,England,20
# "2020-07-13",nation,E92000001,England,22
# "2020-07-12",nation,E92000001,England,12
# "2020-07-11",nation,E92000001,England,21
# "2020-07-10",nation,E92000001,England,21
# "2020-07-09",nation,E92000001,England,35
# "2020-07-08",nation,E92000001,England,23
# "2020-07-07",nation,E92000001,England,26
# "2020-07-06",nation,E92000001,England,33
# "2020-07-05",nation,E92000001,England,24
# "2020-07-04",nation,E92000001,England,31
# "2020-07-03",nation,E92000001,England,26
# "2020-07-02",nation,E92000001,England,40
# "2020-07-01",nation,E92000001,England,22
# "2020-06-30",nation,E92000001,England,43
# "2020-06-29",nation,E92000001,England,34
# "2020-06-28",nation,E92000001,England,42
# "2020-06-27",nation,E92000001,England,39
# "2020-06-26",nation,E92000001,England,37
# "2020-06-25",nation,E92000001,England,58
# "2020-06-24",nation,E92000001,England,68
# "2020-06-23",nation,E92000001,England,61
# "2020-06-22",nation,E92000001,England,58
# "2020-06-21",nation,E92000001,England,47
# "2020-06-20",nation,E92000001,England,54
# "2020-06-19",nation,E92000001,England,47
# "2020-06-18",nation,E92000001,England,57
# "2020-06-17",nation,E92000001,England,53
# "2020-06-16",nation,E92000001,England,69
# "2020-06-15",nation,E92000001,England,61
# "2020-06-14",nation,E92000001,England,76
# "2020-06-13",nation,E92000001,England,53
# "2020-06-12",nation,E92000001,England,72
# "2020-06-11",nation,E92000001,England,71
# "2020-06-10",nation,E92000001,England,97
# "2020-06-09",nation,E92000001,England,85
# "2020-06-08",nation,E92000001,England,111
# "2020-06-07",nation,E92000001,England,112
# "2020-06-06",nation,E92000001,England,99
# "2020-06-05",nation,E92000001,England,108
# "2020-06-04",nation,E92000001,England,120
# "2020-06-03",nation,E92000001,England,138
# "2020-06-02",nation,E92000001,England,156
# "2020-06-01",nation,E92000001,England,122
# "2020-05-31",nation,E92000001,England,112
# "2020-05-30",nation,E92000001,England,145
# "2020-05-29",nation,E92000001,England,163
# "2020-05-28",nation,E92000001,England,182
# "2020-05-27",nation,E92000001,England,171
# "2020-05-26",nation,E92000001,England,188
# "2020-05-25",nation,E92000001,England,176
# "2020-05-24",nation,E92000001,England,169
# "2020-05-23",nation,E92000001,England,198
# "2020-05-22",nation,E92000001,England,195
# "2020-05-21",nation,E92000001,England,201
# "2020-05-20",nation,E92000001,England,234
# "2020-05-19",nation,E92000001,England,231
# "2020-05-18",nation,E92000001,England,253
# "2020-05-17",nation,E92000001,England,222
# "2020-05-16",nation,E92000001,England,268
# "2020-05-15",nation,E92000001,England,269
# "2020-05-14",nation,E92000001,England,277
# "2020-05-13",nation,E92000001,England,255
# "2020-05-12",nation,E92000001,England,275
# "2020-05-11",nation,E92000001,England,260
# "2020-05-10",nation,E92000001,England,300
# "2020-05-09",nation,E92000001,England,330
# "2020-05-08",nation,E92000001,England,328
# "2020-05-07",nation,E92000001,England,399
# "2020-05-06",nation,E92000001,England,392
# "2020-05-05",nation,E92000001,England,390
# "2020-05-04",nation,E92000001,England,411
# "2020-05-03",nation,E92000001,England,387
# "2020-05-02",nation,E92000001,England,423
# "2020-05-01",nation,E92000001,England,478
# "2020-04-30",nation,E92000001,England,482
# "2020-04-29",nation,E92000001,England,492
# "2020-04-28",nation,E92000001,England,498
# "2020-04-27",nation,E92000001,England,506
# "2020-04-26",nation,E92000001,England,560
# "2020-04-25",nation,E92000001,England,555
# "2020-04-24",nation,E92000001,England,602
# "2020-04-23",nation,E92000001,England,592
# "2020-04-22",nation,E92000001,England,642
# "2020-04-21",nation,E92000001,England,649
# "2020-04-20",nation,E92000001,England,684
# "2020-04-19",nation,E92000001,England,683
# "2020-04-18",nation,E92000001,England,706
# "2020-04-17",nation,E92000001,England,744
# "2020-04-16",nation,E92000001,England,751
# "2020-04-15",nation,E92000001,England,784
# "2020-04-14",nation,E92000001,England,771
# "2020-04-13",nation,E92000001,England,804
# "2020-04-12",nation,E92000001,England,858
# "2020-04-11",nation,E92000001,England,862
# "2020-04-10",nation,E92000001,England,850
# "2020-04-09",nation,E92000001,England,874
# "2020-04-08",nation,E92000001,England,974
# "2020-04-07",nation,E92000001,England,912
# "2020-04-06",nation,E92000001,England,804
# "2020-04-05",nation,E92000001,England,829
# "2020-04-04",nation,E92000001,England,837
# "2020-04-03",nation,E92000001,England,743
# "2020-04-02",nation,E92000001,England,731
# "2020-04-01",nation,E92000001,England,698
# "2020-03-31",nation,E92000001,England,603
# "2020-03-30",nation,E92000001,England,538
# "2020-03-29",nation,E92000001,England,465
# "2020-03-28",nation,E92000001,England,384
# "2020-03-27",nation,E92000001,England,375
# "2020-03-26",nation,E92000001,England,336
# "2020-03-25",nation,E92000001,England,278
# "2020-03-24",nation,E92000001,England,219
# "2020-03-23",nation,E92000001,England,173
# "2020-03-21",nation,E92000001,England,117
# "2020-03-20",nation,E92000001,England,102
# "2020-03-19",nation,E92000001,England,67
# "2020-03-18",nation,E92000001,England,67
# "2020-03-17",nation,E92000001,England,50
# "2020-03-16",nation,E92000001,England,42
# "2020-03-15",nation,E92000001,England,32
# "2020-03-14",nation,E92000001,England,20
# "2020-03-13",nation,E92000001,England,16
# "2020-03-12",nation,E92000001,England,12
# "2020-03-11",nation,E92000001,England,8
# "2020-03-10",nation,E92000001,England,3
# "2020-03-09",nation,E92000001,England,5
# "2020-03-08",nation,E92000001,England,3
# "2020-03-07",nation,E92000001,England,0
# "2020-03-06",nation,E92000001,England,0
# "2020-03-05",nation,E92000001,England,3
# "2020-03-04",nation,E92000001,England,0
# "2020-03-03",nation,E92000001,England,2
# "2020-03-02",nation,E92000001,England,1
# "2020-03-22",nation,E92000001,England,154

# %%
from datetime import datetime, timedelta
from time import sleep

import os

# %%
def daterange(start_date, end_date):
    for n in range( int( (end_date - start_date).days ) + 1 ):
        yield start_date + timedelta(n)

# %%
def get_new_releases():
    
    if 'DATA' not in os.listdir():
        os.mkdir('DATA')
        last_dl = datetime(2020,8,23)
    else:
        last_dl = sorted([f for f in os.listdir('./DATA') if f.startswith('phe_overview')])
        last_dl = last_dl[-1]
        last_dl = last_dl[13:-4].split('-')
        last_dl = [int(s) for s in last_dl]
        last_dl = datetime(last_dl[0],last_dl[1],last_dl[2])

    today = datetime.now()
    
    release_dates = [d.strftime('%Y-%m-%d') for d in daterange(last_dl,today)]
    
    url_start = 'https://api.coronavirus.data.gov.uk/v2/data?areaType=nation&areaCode=E92000001&metric=newDeaths28DaysByDeathDate&format=csv&release='
    
    # initialise a log
    with open('log.txt', 'a') as f:
        f.write( 'Log for ' + today.strftime("%d-%b, '%y at %H:%M\n\n") )

    for rd in release_dates:
        url = url_start + rd #<-- 'release' is the last parameter in the query, so this concat will generate a valid query for each item in release_dates
        filename = './DATA/phe_overview_'+rd+'.csv'
        res = requests.get(url)
        response_code = str(res.status_code)

    #    some retry attempts and response-code logging incase of bad requests…
    
        count = 0
        while res.status_code in [429, 500] and count < 2:
            count += 1
            sleep(5)
            res = requests.get(url)
            with open('log.txt', 'a') as f:
                f.write(rd+'\t'+str(count)+'\t'+response_code+'\n')

        while res.status_code in [429, 500] and count < 4:
            sleep(155)
            count += 1
            with open('log.txt', 'a') as f:
                f.write(rd+'\t'+str(count)+'\t'+response_code+'\n')

    #    save response text as a .csv file…

        with open(filename, 'w') as f:
            f.write(res.text)

        sleep(11) #<-- Fair use policy allows a maximum of 10 requests every 100 seconds

# %%
get_new_releases()

# %% [markdown]
# After running, the following files had been created. I cast the filenames from an os.listdir() to a list.

# %%
releases = [f for f in os.listdir('./DATA') if f.startswith('phe_overview')]

releases.sort()

releases
# Out:
# ['phe_overview_2020-08-23.csv',
#  'phe_overview_2020-08-24.csv',
#  'phe_overview_2020-08-25.csv',
#  'phe_overview_2020-08-26.csv',
#  'phe_overview_2020-08-27.csv',
#  'phe_overview_2020-08-28.csv',
#  'phe_overview_2020-08-29.csv',
#  'phe_overview_2020-08-30.csv',
#  'phe_overview_2020-08-31.csv',
#  'phe_overview_2020-09-01.csv',
#  'phe_overview_2020-09-02.csv',
#  'phe_overview_2020-09-03.csv',
#  'phe_overview_2020-09-04.csv',
#  'phe_overview_2020-09-05.csv',
#  'phe_overview_2020-09-06.csv',
#  'phe_overview_2020-09-07.csv',
#  'phe_overview_2020-09-08.csv',
#  'phe_overview_2020-09-09.csv',
#  'phe_overview_2020-09-10.csv',
#  'phe_overview_2020-09-11.csv',
#  'phe_overview_2020-09-12.csv',
#  'phe_overview_2020-09-13.csv',
#  'phe_overview_2020-09-14.csv',
#  'phe_overview_2020-09-15.csv',
#  'phe_overview_2020-09-16.csv',
#  'phe_overview_2020-09-17.csv',
#  'phe_overview_2020-09-18.csv',
#  'phe_overview_2020-09-19.csv',
#  'phe_overview_2020-09-20.csv',
#  'phe_overview_2020-09-21.csv',
#  'phe_overview_2020-09-22.csv',
#  'phe_overview_2020-09-23.csv',
#  'phe_overview_2020-09-24.csv',
#  'phe_overview_2020-09-25.csv',
#  'phe_overview_2020-09-26.csv',
#  'phe_overview_2020-09-27.csv',
#  'phe_overview_2020-09-28.csv',
#  'phe_overview_2020-09-29.csv',
#  'phe_overview_2020-09-30.csv',
#  'phe_overview_2020-10-01.csv',
#  'phe_overview_2020-10-02.csv',
#  'phe_overview_2020-10-03.csv',
#  'phe_overview_2020-10-04.csv',
#  'phe_overview_2020-10-05.csv',
#  'phe_overview_2020-10-06.csv',
#  'phe_overview_2020-10-07.csv',
#  'phe_overview_2020-10-08.csv',
#  'phe_overview_2020-10-09.csv',
#  'phe_overview_2020-10-10.csv',
#  'phe_overview_2020-10-11.csv',
#  'phe_overview_2020-10-12.csv',
#  'phe_overview_2020-10-13.csv',
#  'phe_overview_2020-10-14.csv',
#  'phe_overview_2020-10-15.csv',
#  'phe_overview_2020-10-16.csv',
#  'phe_overview_2020-10-17.csv',
#  'phe_overview_2020-10-18.csv',
#  'phe_overview_2020-10-19.csv',
#  'phe_overview_2020-10-20.csv',
#  'phe_overview_2020-10-21.csv',
#  'phe_overview_2020-10-22.csv',
#  'phe_overview_2020-10-23.csv',
#  'phe_overview_2020-10-24.csv',
#  'phe_overview_2020-10-25.csv',
#  'phe_overview_2020-10-26.csv',
#  'phe_overview_2020-10-27.csv',
#  'phe_overview_2020-10-28.csv',
#  'phe_overview_2020-10-29.csv',
#  'phe_overview_2020-10-30.csv',
#  'phe_overview_2020-10-31.csv',
#  'phe_overview_2020-11-01.csv',
#  'phe_overview_2020-11-02.csv',
#  'phe_overview_2020-11-03.csv',
#  'phe_overview_2020-11-04.csv',
#  'phe_overview_2020-11-05.csv',
#  'phe_overview_2020-11-06.csv',
#  'phe_overview_2020-11-07.csv',
#  'phe_overview_2020-11-08.csv',
#  'phe_overview_2020-11-09.csv',
#  'phe_overview_2020-11-10.csv',
#  'phe_overview_2020-11-11.csv',
#  'phe_overview_2020-11-12.csv',
#  'phe_overview_2020-11-13.csv',
#  'phe_overview_2020-11-14.csv',
#  'phe_overview_2020-11-15.csv',
#  'phe_overview_2020-11-16.csv',
#  'phe_overview_2020-11-17.csv',
#  'phe_overview_2020-11-18.csv',
#  'phe_overview_2020-11-19.csv',
#  'phe_overview_2020-11-20.csv',
#  'phe_overview_2020-11-21.csv',
#  'phe_overview_2020-11-22.csv',
#  'phe_overview_2020-11-23.csv',
#  'phe_overview_2020-11-24.csv',
#  'phe_overview_2020-11-25.csv',
#  'phe_overview_2020-11-26.csv',
#  'phe_overview_2020-11-27.csv',
#  'phe_overview_2020-11-28.csv',
#  'phe_overview_2020-11-29.csv',
#  'phe_overview_2020-11-30.csv',
#  'phe_overview_2020-12-01.csv',
#  'phe_overview_2020-12-02.csv',
#  'phe_overview_2020-12-03.csv',
#  'phe_overview_2020-12-04.csv',
#  'phe_overview_2020-12-05.csv',
#  'phe_overview_2020-12-06.csv',
#  'phe_overview_2020-12-07.csv',
#  'phe_overview_2020-12-08.csv',
#  'phe_overview_2020-12-09.csv',
#  'phe_overview_2020-12-10.csv',
#  'phe_overview_2020-12-11.csv',
#  'phe_overview_2020-12-12.csv',
#  'phe_overview_2020-12-13.csv',
#  'phe_overview_2020-12-14.csv',
#  'phe_overview_2020-12-15.csv',
#  'phe_overview_2020-12-16.csv',
#  'phe_overview_2020-12-17.csv',
#  'phe_overview_2020-12-18.csv',
#  'phe_overview_2020-12-19.csv',
#  'phe_overview_2020-12-20.csv',
#  'phe_overview_2020-12-21.csv',
#  'phe_overview_2020-12-22.csv',
#  'phe_overview_2020-12-23.csv',
#  'phe_overview_2020-12-24.csv',
#  'phe_overview_2020-12-25.csv',
#  'phe_overview_2020-12-26.csv',
#  'phe_overview_2020-12-27.csv',
#  'phe_overview_2020-12-28.csv',
#  'phe_overview_2020-12-29.csv',
#  'phe_overview_2020-12-30.csv',
#  'phe_overview_2020-12-31.csv',
#  'phe_overview_2021-01-01.csv',
#  'phe_overview_2021-01-02.csv',
#  'phe_overview_2021-01-03.csv',
#  'phe_overview_2021-01-04.csv',
#  'phe_overview_2021-01-05.csv',
#  'phe_overview_2021-01-06.csv',
#  'phe_overview_2021-01-07.csv',
#  'phe_overview_2021-01-08.csv',
#  'phe_overview_2021-01-09.csv',
#  'phe_overview_2021-01-10.csv',
#  'phe_overview_2021-01-11.csv',
#  'phe_overview_2021-01-12.csv',
#  'phe_overview_2021-01-13.csv',
#  'phe_overview_2021-01-14.csv',
#  'phe_overview_2021-01-15.csv',
#  'phe_overview_2021-01-16.csv',
#  'phe_overview_2021-01-17.csv',
#  'phe_overview_2021-01-18.csv',
#  'phe_overview_2021-01-19.csv',
#  'phe_overview_2021-01-20.csv',
#  'phe_overview_2021-01-21.csv',
#  'phe_overview_2021-01-22.csv',
#  'phe_overview_2021-01-23.csv',
#  'phe_overview_2021-01-24.csv',
#  'phe_overview_2021-01-25.csv',
#  'phe_overview_2021-01-26.csv',
#  'phe_overview_2021-01-27.csv']

# %%
# Quick check on one of the files for formatting and content:

with open(f'./DATA/{releases[-3]}', 'r') as f:
    print(f.read())
# Out:
# date,areaType,areaCode,areaName,newDeaths28DaysByDeathDate
# "2021-01-24",nation,E92000001,England,142
# "2021-01-23",nation,E92000001,England,378
# "2021-01-22",nation,E92000001,England,626
# "2021-01-21",nation,E92000001,England,873
# "2021-01-20",nation,E92000001,England,949
# "2021-01-19",nation,E92000001,England,1059
# "2021-01-18",nation,E92000001,England,1062
# "2021-01-17",nation,E92000001,England,1033
# "2021-01-16",nation,E92000001,England,1040
# "2021-01-15",nation,E92000001,England,989
# "2021-01-14",nation,E92000001,England,1016
# "2021-01-13",nation,E92000001,England,1043
# "2021-01-12",nation,E92000001,England,1052
# "2021-01-11",nation,E92000001,England,996
# "2021-01-10",nation,E92000001,England,940
# "2021-01-09",nation,E92000001,England,910
# "2021-01-08",nation,E92000001,England,859
# "2021-01-07",nation,E92000001,England,875
# "2021-01-06",nation,E92000001,England,811
# "2021-01-05",nation,E92000001,England,812
# "2021-01-04",nation,E92000001,England,740
# "2021-01-03",nation,E92000001,England,639
# "2021-01-02",nation,E92000001,England,661
# "2021-01-01",nation,E92000001,England,631
# "2020-12-31",nation,E92000001,England,641
# "2020-12-30",nation,E92000001,England,620
# "2020-12-29",nation,E92000001,England,577
# "2020-12-28",nation,E92000001,England,588
# "2020-12-27",nation,E92000001,England,569
# "2020-12-26",nation,E92000001,England,565
# "2020-12-25",nation,E92000001,England,534
# "2020-12-24",nation,E92000001,England,479
# "2020-12-23",nation,E92000001,England,484
# "2020-12-22",nation,E92000001,England,490
# "2020-12-21",nation,E92000001,England,489
# "2020-12-20",nation,E92000001,England,429
# "2020-12-19",nation,E92000001,England,408
# "2020-12-18",nation,E92000001,England,433
# "2020-12-17",nation,E92000001,England,435
# "2020-12-16",nation,E92000001,England,355
# "2020-12-15",nation,E92000001,England,386
# "2020-12-14",nation,E92000001,England,413
# "2020-12-13",nation,E92000001,England,363
# "2020-12-12",nation,E92000001,England,374
# "2020-12-11",nation,E92000001,England,399
# "2020-12-10",nation,E92000001,England,374
# "2020-12-09",nation,E92000001,England,372
# "2020-12-08",nation,E92000001,England,375
# "2020-12-07",nation,E92000001,England,353
# "2020-12-06",nation,E92000001,England,351
# "2020-12-05",nation,E92000001,England,342
# "2020-12-04",nation,E92000001,England,414
# "2020-12-03",nation,E92000001,England,403
# "2020-12-02",nation,E92000001,England,336
# "2020-12-01",nation,E92000001,England,349
# "2020-11-30",nation,E92000001,England,360
# "2020-11-29",nation,E92000001,England,401
# "2020-11-28",nation,E92000001,England,379
# "2020-11-27",nation,E92000001,England,360
# "2020-11-26",nation,E92000001,England,371
# "2020-11-25",nation,E92000001,England,423
# "2020-11-24",nation,E92000001,England,402
# "2020-11-23",nation,E92000001,England,400
# "2020-11-22",nation,E92000001,England,407
# "2020-11-21",nation,E92000001,England,395
# "2020-11-20",nation,E92000001,England,388
# "2020-11-19",nation,E92000001,England,397
# "2020-11-18",nation,E92000001,England,435
# "2020-11-17",nation,E92000001,England,363
# "2020-11-16",nation,E92000001,England,359
# "2020-11-15",nation,E92000001,England,380
# "2020-11-14",nation,E92000001,England,357
# "2020-11-13",nation,E92000001,England,358
# "2020-11-12",nation,E92000001,England,350
# "2020-11-11",nation,E92000001,England,310
# "2020-11-10",nation,E92000001,England,318
# "2020-11-09",nation,E92000001,England,403
# "2020-11-08",nation,E92000001,England,340
# "2020-11-07",nation,E92000001,England,333
# "2020-11-06",nation,E92000001,England,334
# "2020-11-05",nation,E92000001,England,300
# "2020-11-04",nation,E92000001,England,278
# "2020-11-03",nation,E92000001,England,292
# "2020-11-02",nation,E92000001,England,281
# "2020-11-01",nation,E92000001,England,286
# "2020-10-31",nation,E92000001,England,276
# "2020-10-30",nation,E92000001,England,280
# "2020-10-29",nation,E92000001,England,249
# "2020-10-28",nation,E92000001,England,238
# "2020-10-27",nation,E92000001,England,218
# "2020-10-26",nation,E92000001,England,222
# "2020-10-25",nation,E92000001,England,204
# "2020-10-24",nation,E92000001,England,171
# "2020-10-23",nation,E92000001,England,188
# "2020-10-22",nation,E92000001,England,185
# "2020-10-21",nation,E92000001,England,192
# "2020-10-20",nation,E92000001,England,171
# "2020-10-19",nation,E92000001,England,159
# "2020-10-18",nation,E92000001,England,120
# "2020-10-17",nation,E92000001,England,160
# "2020-10-16",nation,E92000001,England,123
# "2020-10-15",nation,E92000001,England,124
# "2020-10-14",nation,E92000001,England,100
# "2020-10-13",nation,E92000001,England,87
# "2020-10-12",nation,E92000001,England,96
# "2020-10-11",nation,E92000001,England,103
# "2020-10-10",nation,E92000001,England,90
# "2020-10-09",nation,E92000001,England,67
# "2020-10-08",nation,E92000001,England,75
# "2020-10-07",nation,E92000001,England,82
# "2020-10-06",nation,E92000001,England,61
# "2020-10-05",nation,E92000001,England,59
# "2020-10-04",nation,E92000001,England,54
# "2020-10-03",nation,E92000001,England,55
# "2020-10-02",nation,E92000001,England,63
# "2020-10-01",nation,E92000001,England,56
# "2020-09-30",nation,E92000001,England,48
# "2020-09-29",nation,E92000001,England,43
# "2020-09-28",nation,E92000001,England,47
# "2020-09-27",nation,E92000001,England,42
# "2020-09-26",nation,E92000001,England,35
# "2020-09-25",nation,E92000001,England,29
# "2020-09-24",nation,E92000001,England,33
# "2020-09-23",nation,E92000001,England,52
# "2020-09-22",nation,E92000001,England,34
# "2020-09-21",nation,E92000001,England,24
# "2020-09-20",nation,E92000001,England,27
# "2020-09-19",nation,E92000001,England,18
# "2020-09-18",nation,E92000001,England,21
# "2020-09-17",nation,E92000001,England,24
# "2020-09-16",nation,E92000001,England,22
# "2020-09-15",nation,E92000001,England,15
# "2020-09-14",nation,E92000001,England,17
# "2020-09-13",nation,E92000001,England,14
# "2020-09-12",nation,E92000001,England,18
# "2020-09-11",nation,E92000001,England,10
# "2020-09-10",nation,E92000001,England,12
# "2020-09-09",nation,E92000001,England,9
# "2020-09-08",nation,E92000001,England,9
# "2020-09-07",nation,E92000001,England,13
# "2020-09-06",nation,E92000001,England,8
# "2020-09-05",nation,E92000001,England,12
# "2020-09-04",nation,E92000001,England,6
# "2020-09-03",nation,E92000001,England,6
# "2020-09-02",nation,E92000001,England,8
# "2020-09-01",nation,E92000001,England,2
# "2020-08-31",nation,E92000001,England,7
# "2020-08-30",nation,E92000001,England,6
# "2020-08-29",nation,E92000001,England,5
# "2020-08-28",nation,E92000001,England,8
# "2020-08-27",nation,E92000001,England,8
# "2020-08-26",nation,E92000001,England,11
# "2020-08-25",nation,E92000001,England,11
# "2020-08-24",nation,E92000001,England,5
# "2020-08-23",nation,E92000001,England,13
# "2020-08-22",nation,E92000001,England,6
# "2020-08-21",nation,E92000001,England,7
# "2020-08-20",nation,E92000001,England,8
# "2020-08-19",nation,E92000001,England,2
# "2020-08-18",nation,E92000001,England,7
# "2020-08-17",nation,E92000001,England,12
# "2020-08-16",nation,E92000001,England,4
# "2020-08-15",nation,E92000001,England,11
# "2020-08-14",nation,E92000001,England,6
# "2020-08-13",nation,E92000001,England,7
# "2020-08-12",nation,E92000001,England,6
# "2020-08-11",nation,E92000001,England,10
# "2020-08-10",nation,E92000001,England,11
# "2020-08-09",nation,E92000001,England,8
# "2020-08-08",nation,E92000001,England,11
# "2020-08-07",nation,E92000001,England,8
# "2020-08-06",nation,E92000001,England,9
# "2020-08-05",nation,E92000001,England,3
# "2020-08-04",nation,E92000001,England,10
# "2020-08-03",nation,E92000001,England,14
# "2020-08-02",nation,E92000001,England,8
# "2020-08-01",nation,E92000001,England,9
# "2020-07-31",nation,E92000001,England,10
# "2020-07-30",nation,E92000001,England,8
# "2020-07-29",nation,E92000001,England,8
# "2020-07-28",nation,E92000001,England,10
# "2020-07-27",nation,E92000001,England,10
# "2020-07-26",nation,E92000001,England,14
# "2020-07-25",nation,E92000001,England,14
# "2020-07-24",nation,E92000001,England,6
# "2020-07-23",nation,E92000001,England,16
# "2020-07-22",nation,E92000001,England,16
# "2020-07-21",nation,E92000001,England,19
# "2020-07-20",nation,E92000001,England,12
# "2020-07-19",nation,E92000001,England,14
# "2020-07-18",nation,E92000001,England,15
# "2020-07-17",nation,E92000001,England,18
# "2020-07-16",nation,E92000001,England,12
# "2020-07-15",nation,E92000001,England,21
# "2020-07-14",nation,E92000001,England,20
# "2020-07-13",nation,E92000001,England,22
# "2020-07-12",nation,E92000001,England,12
# "2020-07-11",nation,E92000001,England,20
# "2020-07-10",nation,E92000001,England,21
# "2020-07-09",nation,E92000001,England,35
# "2020-07-08",nation,E92000001,England,23
# "2020-07-07",nation,E92000001,England,26
# "2020-07-06",nation,E92000001,England,34
# "2020-07-05",nation,E92000001,England,24
# "2020-07-04",nation,E92000001,England,31
# "2020-07-03",nation,E92000001,England,26
# "2020-07-02",nation,E92000001,England,40
# "2020-07-01",nation,E92000001,England,22
# "2020-06-30",nation,E92000001,England,43
# "2020-06-29",nation,E92000001,England,34
# "2020-06-28",nation,E92000001,England,42
# "2020-06-27",nation,E92000001,England,39
# "2020-06-26",nation,E92000001,England,37
# "2020-06-25",nation,E92000001,England,58
# "2020-06-24",nation,E92000001,England,68
# "2020-06-23",nation,E92000001,England,61
# "2020-06-22",nation,E92000001,England,58
# "2020-06-21",nation,E92000001,England,47
# "2020-06-20",nation,E92000001,England,54
# "2020-06-19",nation,E92000001,England,47
# "2020-06-18",nation,E92000001,England,57
# "2020-06-17",nation,E92000001,England,53
# "2020-06-16",nation,E92000001,England,69
# "2020-06-15",nation,E92000001,England,61
# "2020-06-14",nation,E92000001,England,76
# "2020-06-13",nation,E92000001,England,53
# "2020-06-12",nation,E92000001,England,72
# "2020-06-11",nation,E92000001,England,71
# "2020-06-10",nation,E92000001,England,97
# "2020-06-09",nation,E92000001,England,85
# "2020-06-08",nation,E92000001,England,111
# "2020-06-07",nation,E92000001,England,112
# "2020-06-06",nation,E92000001,England,99
# "2020-06-05",nation,E92000001,England,109
# "2020-06-04",nation,E92000001,England,121
# "2020-06-03",nation,E92000001,England,138
# "2020-06-02",nation,E92000001,England,156
# "2020-06-01",nation,E92000001,England,122
# "2020-05-31",nation,E92000001,England,112
# "2020-05-30",nation,E92000001,England,145
# "2020-05-29",nation,E92000001,England,163
# "2020-05-28",nation,E92000001,England,182
# "2020-05-27",nation,E92000001,England,171
# "2020-05-26",nation,E92000001,England,188
# "2020-05-25",nation,E92000001,England,176
# "2020-05-24",nation,E92000001,England,169
# "2020-05-23",nation,E92000001,England,199
# "2020-05-22",nation,E92000001,England,195
# "2020-05-21",nation,E92000001,England,201
# "2020-05-20",nation,E92000001,England,234
# "2020-05-19",nation,E92000001,England,231
# "2020-05-18",nation,E92000001,England,253
# "2020-05-17",nation,E92000001,England,223
# "2020-05-16",nation,E92000001,England,268
# "2020-05-15",nation,E92000001,England,269
# "2020-05-14",nation,E92000001,England,277
# "2020-05-13",nation,E92000001,England,255
# "2020-05-12",nation,E92000001,England,275
# "2020-05-11",nation,E92000001,England,260
# "2020-05-10",nation,E92000001,England,300
# "2020-05-09",nation,E92000001,England,330
# "2020-05-08",nation,E92000001,England,330
# "2020-05-07",nation,E92000001,England,400
# "2020-05-06",nation,E92000001,England,392
# "2020-05-05",nation,E92000001,England,391
# "2020-05-04",nation,E92000001,England,412
# "2020-05-03",nation,E92000001,England,387
# "2020-05-02",nation,E92000001,England,424
# "2020-05-01",nation,E92000001,England,479
# "2020-04-30",nation,E92000001,England,484
# "2020-04-29",nation,E92000001,England,493
# "2020-04-28",nation,E92000001,England,499
# "2020-04-27",nation,E92000001,England,506
# "2020-04-26",nation,E92000001,England,561
# "2020-04-25",nation,E92000001,England,555
# "2020-04-24",nation,E92000001,England,603
# "2020-04-23",nation,E92000001,England,593
# "2020-04-22",nation,E92000001,England,643
# "2020-04-21",nation,E92000001,England,649
# "2020-04-20",nation,E92000001,England,685
# "2020-04-19",nation,E92000001,England,685
# "2020-04-18",nation,E92000001,England,706
# "2020-04-17",nation,E92000001,England,744
# "2020-04-16",nation,E92000001,England,752
# "2020-04-15",nation,E92000001,England,784
# "2020-04-14",nation,E92000001,England,771
# "2020-04-13",nation,E92000001,England,804
# "2020-04-12",nation,E92000001,England,858
# "2020-04-11",nation,E92000001,England,862
# "2020-04-10",nation,E92000001,England,850
# "2020-04-09",nation,E92000001,England,875
# "2020-04-08",nation,E92000001,England,975
# "2020-04-07",nation,E92000001,England,912
# "2020-04-06",nation,E92000001,England,804
# "2020-04-05",nation,E92000001,England,830
# "2020-04-04",nation,E92000001,England,838
# "2020-04-03",nation,E92000001,England,743
# "2020-04-02",nation,E92000001,England,732
# "2020-04-01",nation,E92000001,England,698
# "2020-03-31",nation,E92000001,England,603
# "2020-03-30",nation,E92000001,England,539
# "2020-03-29",nation,E92000001,England,465
# "2020-03-28",nation,E92000001,England,384
# "2020-03-27",nation,E92000001,England,374
# "2020-03-26",nation,E92000001,England,336
# "2020-03-25",nation,E92000001,England,278
# "2020-03-24",nation,E92000001,England,219
# "2020-03-23",nation,E92000001,England,173
# "2020-03-22",nation,E92000001,England,154
# "2020-03-21",nation,E92000001,England,117
# "2020-03-20",nation,E92000001,England,102
# "2020-03-19",nation,E92000001,England,67
# "2020-03-18",nation,E92000001,England,67
# "2020-03-17",nation,E92000001,England,50
# "2020-03-16",nation,E92000001,England,42
# "2020-03-15",nation,E92000001,England,32
# "2020-03-14",nation,E92000001,England,20
# "2020-03-13",nation,E92000001,England,16
# "2020-03-12",nation,E92000001,England,12
# "2020-03-11",nation,E92000001,England,8
# "2020-03-10",nation,E92000001,England,3
# "2020-03-09",nation,E92000001,England,5
# "2020-03-08",nation,E92000001,England,3
# "2020-03-07",nation,E92000001,England,0
# "2020-03-06",nation,E92000001,England,0
# "2020-03-05",nation,E92000001,England,3
# "2020-03-04",nation,E92000001,England,0
# "2020-03-03",nation,E92000001,England,2
# "2020-03-02",nation,E92000001,England,1

# %% [markdown]
# The request for 2020-10-07 persistently responded with a 500 error. Consequently, the corresponding .csv file is empty.

# %%
with open('./DATA/phe_overview_2020-10-07.csv', 'r') as f:
    print(len(f.read()))
# Out:
# 0

# %% [markdown]
# In order to work with the dataset in pandas and matplotlib, I either need to drop this release from the dataset or fill it in somehow. Since it's only the data from a single release, I'm more comfortable dropping it entirely than attempting to infer values from the other releases. I'm trying to analyse how releases differ with respect to each other, so to invent data for one such release doesn't seem like the right thing to do.

# %%
print(len(releases))

releases.remove('phe_overview_2020-10-07.csv')

print(len(releases))
# Out:
# 158
# 157

# %% [markdown]
# ## Load data into pandas

# %%
import pandas as pd

# %% [markdown]
# First, I'll check out how a single .csv looks when loaded into a dataframe

# %%
df0 = pd.read_csv('./DATA/'+releases[-1], parse_dates=[0])

df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   date                        331 non-null    datetime64[ns]
#  1   areaType                    331 non-null    object
#  2   areaCode                    331 non-null    object
#  3   areaName                    331 non-null    object
#  4   newDeaths28DaysByDeathDate  331 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 13.1+ KB

# %% [markdown]
# So far so good. Since there are no fractional deaths, I'll convert to int after I load the full dataset.
#
# As a quick sanity check, I make sure that each day of the week is equally represented across the dates of death.

# %%
df0['date'].apply(lambda d:d.dayofweek).value_counts()
# Out:
# 1    48
# 0    48
# 6    47
# 5    47
# 4    47
# 3    47
# 2    47
# Name: date, dtype: int64

# %% [markdown]
# At this point, I'm happy to load the rest of the data set. The following loop uses an outer merge, since each release introduces a new date for which previous releases have no data. I'm not interested in areaType, areaCode, or areaName: they are the same for every entry in every release and not relevant to the analysis I want to perform. I only read in the date of death (column 0) and the death count (column 4). The result is a union of reported death counts per date of death from all valid releases.

# %%
df = pd.DataFrame(columns=['DoD'])

for r in releases:
    df_r = pd.read_csv('./DATA/'+r, parse_dates=[0], usecols=[0,4], dtype={'newDeaths28DaysByDeathDate':'Int64'})
    release_date = pd.Timestamp(r[13:-4])
    df_r = df_r.rename(columns={'date':'DoD','newDeaths28DaysByDeathDate':release_date})
    df = pd.merge(df, df_r, how='outer', on='DoD')

# %% [markdown]
# The pandas documentation recommends arranging variables by column and observations by row. I considered each release to count as a new observation, so I rearranged the dataframe to have a column for each date of death, so each row stores the death count on each date of death, as reported on that particular release date. This was also a convenient format for producing graphs of reported deaths plotted against release date.
#
# _In hindsight, I might have kept the columns as the releases and rows as date of death. This would make it easier to add columns of more descriptive data to the end of the df. It's not difficult to then use filtering and transforms to make the data fit for graphing._

# %%
df = df.set_index('DoD').sort_index().dropna(thresh=1).transpose().sort_index()

df.index.name = 'Release Date'

df = df.set_index(pd.DatetimeIndex(df.index))

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 157 entries, 2020-08-23 to 2021-01-27
# Columns: 331 entries, 2020-03-02 to 2021-01-26
# dtypes: Int64(331)
# memory usage: 458.0 KB
# None
#               2020-03-02  2020-03-03  2020-03-04  2020-03-05  2020-03-06  \
# Release Date
# 2020-08-23             1           2        <NA>           3        <NA>
# 2020-08-24             1           2        <NA>           3        <NA>
# 2020-08-25             1           2        <NA>           3        <NA>
# 2020-08-26             1           2        <NA>           3        <NA>
# 2020-08-27             1           2        <NA>           3        <NA>
#
#               2020-03-07  2020-03-08  2020-03-09  2020-03-10  2020-03-11  ...  \
# Release Date                                                              ...
# 2020-08-23          <NA>           3           5           3           8  ...
# 2020-08-24          <NA>           3           5           3           8  ...
# 2020-08-25          <NA>           3           5           3           8  ...
# 2020-08-26          <NA>           3           5           3           8  ...
# 2020-08-27          <NA>           3           5           3           8  ...
#
#               2021-01-17  2021-01-18  2021-01-19  2021-01-20  2021-01-21  \
# Release Date
# 2020-08-23          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-24          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-25          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-26          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-27          <NA>        <NA>        <NA>        <NA>        <NA>
#
#               2021-01-22  2021-01-23  2021-01-24  2021-01-25  2021-01-26
# Release Date
# 2020-08-23          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-24          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-25          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-26          <NA>        <NA>        <NA>        <NA>        <NA>
# 2020-08-27          <NA>        <NA>        <NA>        <NA>        <NA>
#
# [5 rows x 331 columns]

# %% [markdown]
# Descriptive statistics for a random sample of dates of death. The 'count' column tells us how many releases include a figure for a given date of death.

# %%
df.describe().round(0).transpose().sample(15).sort_index()
# Out:
#            count mean  std  min  25%  50%  75%  max
# 2020-03-24   157  219    0  219  219  219  219  219
# 2020-03-27   157  375    1  372  374  375  375  375
# 2020-04-23   157  592    0  592  592  592  592  593
# 2020-05-30   157  145    0  143  144  145  145  145
# 2020-06-06   157   98    1   97   98   98   99   99
# 2020-07-27   157   10    0   10   10   10   10   10
# 2020-08-19   157    2    0    0    2    2    2    2
# 2020-09-27   121   40    4    3   40   41   42   42
# 2020-10-04   115   52    7    1   54   54   54   54
# 2020-10-22    97  181   18   42  185  185  185  186
# 2020-11-08    80  329   39   43  338  339  339  341
# 2020-12-09    49  354   45   96  362  371  372  374
# 2020-12-29    29  536   87  144  529  574  577  581
# 2021-01-01    26  540  146   70  542  609  630  635
# 2021-01-04    23  676  141  137  690  736  741  746

# %% [markdown]
# Now I have a dataframe containing the number of deaths occurring on each date from 2 March, as reported in each PHE release from 23 August.

# %% [markdown]
# ## Exploring the data with pandas and matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# For a sanity check, I plotted the most up to date data points for each date of death (.max() for each column) against time. This should produce a graph that is now somewhat familiar, showing the peak of the first wave in April followed by several months of decline and no-growth, followed by the second wave starting in October.
#
# You can see the effect of the underreported statistics in the precipitous drop at the very end of the graph.

# %%
df.max().plot(figsize=(15,4), 
              kind='area', 
              title='COVID-19 deaths in England by date of occurrence', 
              ylabel='Deaths', 
              xlabel='Date of Death')

plt.show()

# %% [markdown]
# To get an idea of how the count changed over time for a date of death with a large discrepancy, I plotted the eight available data points for 2020-11-22.
#
# The release on 23 November 2020 reported around 70 deaths had occurred on 22 November. Over the next seven days, that figure was revised upwards to over 350; more than five times initial figure. The curve has a logarithmic shape, reaching 350 within the first 4 releases.

# %%
plt.figure(dpi=100)
df['2020-11-22'].dropna().plot(title='Deaths occurring on 22 November 2020, as reported in consecutive releases', 
                               ylabel='Reported count')

plt.savefig('countvrelease_nov-22.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# This shape of curve is similar for each of the dates in Aug through Nov.
#
# Next I went back to the full dataset and plotted the difference between the minimum and maximum values across all releases for each date of death:

# %%
maxmin_diff = (df.max()-df.min())
maxmin_diff.plot(figsize=(15,4), 
                 style='k--', 
                 title='Change in reported death count between initial and latest reporting', 
                 ylabel='Difference\n(number of deaths)', 
                 xlabel='Date of Death')

plt.show()

# %% [markdown]
# Taking the dataset as a whole, the average difference between lowest and highest reporting is 41. The median difference is only 2. The death counts for some days did not change between releases. The maximum discrepancy is 328 for 2020-11-15 – the count for this date was initially reported as 48

# %%
maxmin_diff.describe().round(1)
# Out:
# count     331.0
# mean      125.6
# std       214.9
# min         0.0
# 25%         1.0
# 50%         4.0
# 75%       228.0
# max      1051.0
# dtype: float64

# %%
maxmin_diff.nlargest(10)
# Out:
# 2021-01-14    1051
# 2021-01-17     960
# 2021-01-16     958
# 2021-01-10     834
# 2021-01-18     820
# 2021-01-19     809
# 2021-01-09     800
# 2021-01-13     791
# 2021-01-15     791
# 2021-01-12     787
# dtype: int64

# %% [markdown]
# In this dataset, there's close to zero discrepancy between smallest and largest reported values for at least March to August. Following that, the discrepancy grows to a maximum above 300 during the ongoing second wave in November.
#
# It stands to reason that the max-min difference would be greater during a period of rapid growth. It's reasonable to assume that's what we're seeing here in November. A larger number of deaths each day leads to a greater day-to-day increase with each update, and ultimately a final figure far greater than initially reported.
#
# ___TL;DR: The lack of difference between Mar-June is an artefact of the dataset.___ The reason we don't see the same peak during the first lockdown is because the first release in this dataset was published 23 August, by which time the reported daily death count for Mar-Jun has already settled to something approaching the true value. Releases earlier than 23 August were not available through the PHE API, but if I could obtain that data it would be interesting to perform the same max-min analysis for Mar-Apr-May. I suspect that the discrepancy in the first wave would be even greater than that for the second.
#
# **In the remainder of this notebook I'm going to focus on the period of August through January**.

# %%
_ = df.columns.get_loc('2020-08-23')

df = df[df.columns[_:]]

# %%
df.iloc[:,-5]
# Out:
# Release Date
# 2020-08-23    <NA>
# 2020-08-24    <NA>
# 2020-08-25    <NA>
# 2020-08-26    <NA>
# 2020-08-27    <NA>
#               ...
# 2021-01-23    1025
# 2021-01-24    1026
# 2021-01-25    1033
# 2021-01-26    1070
# 2021-01-27    1104
# Name: 2021-01-17 00:00:00, Length: 157, dtype: Int64

# %%
df.describe().round(0).transpose().sample(15).sort_index()
# Out:
#            count mean   std  min  25%  50%  75%   max
# 2020-08-27   152    8     1    0    7    8    8     8
# 2020-09-01   147    2     0    1    2    2    2     4
# 2020-09-05   143   12     1    2   11   12   12    12
# 2020-09-15   133   15     1    5   15   15   15    16
# 2020-10-06   112   60     3   41   61   61   61    61
# 2020-10-19   100  154    15   45  157  158  159   159
# 2020-10-22    97  181    18   42  185  185  185   186
# 2020-10-30    89  271    31   70  280  280  280   280
# 2020-11-03    85  283    29   61  288  291  291   292
# 2020-11-10    78  311    30   71  318  318  318   318
# 2020-11-29    59  385    52   50  399  401  401   403
# 2020-12-10    48  357    51   77  372  376  378   380
# 2021-01-15    12  829   243  277  726  928  984  1068
# 2021-01-21     6  783   247  308  772  854  924   988
# 2021-01-26     1  239  <NA>  239  239  239  239   239

# %% [markdown]
# To get some idea of spread, the cell below plots the standard deviation for each date of death and lists the 30 dates of death with the largest S.D.

# %%
stds = df.describe().loc['std'].dropna().astype(float)

stds.plot(figsize=(15,4), title='Standard deviation for each date of death', ylabel='S.D.', xlabel='Date of Death')
plt.show()

stds.round(1).nlargest(20)
# Out:
# 2021-01-24    335.3
# 2021-01-25    310.4
# 2021-01-14    309.4
# 2021-01-16    301.4
# 2021-01-23    292.5
# 2021-01-17    292.1
# 2021-01-19    264.5
# 2021-01-18    255.4
# 2021-01-20    248.9
# 2021-01-21    246.8
# 2021-01-15    242.8
# 2021-01-22    242.8
# 2021-01-09    220.2
# 2021-01-13    209.7
# 2021-01-10    206.4
# 2021-01-12    204.7
# 2021-01-11    196.2
# 2021-01-08    180.6
# 2021-01-07    159.7
# 2021-01-05    154.4
# Name: std, dtype: float64

# %% [markdown]
# Most of the top 30 dates of death with the largest spread fall in November. The largest standard deviations occur on consecutive days; the 21 and 22. I don't think this tells us anything new. When the death rate outstrips the speed of reporting, the data's always going to be a bit more spread out.
#
# Still, pandas makes it really easy to do this, so nothing gained but nothing lost either.

# %% [markdown]
# ## Charting the discrepancy

# %% [markdown]
# With the above exploration complete, it is relatively straightforward to express what was found graphically.

# %% [markdown]
# Creating the difference plot for this selection:

# %%
minimums = df.min()
maximums = df.max()
differences = maximums - minimums

# %%
differences.describe().round(1)
# Out:
# count     157.0
# mean      263.0
# std       248.0
# min         0.0
# 25%        37.0
# 50%       244.0
# 75%       346.0
# max      1051.0
# dtype: float64

# %%
differences.nlargest(10)
# Out:
# 2021-01-14    1051
# 2021-01-17     960
# 2021-01-16     958
# 2021-01-10     834
# 2021-01-18     820
# 2021-01-19     809
# 2021-01-09     800
# 2021-01-13     791
# 2021-01-15     791
# 2021-01-12     787
# dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True, dpi=100, figsize=(10,4), gridspec_kw={'height_ratios': [3, 1]})
plt.subplots_adjust(hspace=0.02)

minimums.plot(label='count as first reported', legend=True, ax=ax1)
maximums.plot(label='count as of 30 November', legend=True, ax=ax1)
ax1.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title(f'Range of reported counts\nfor dates of death from 23-Aug to 14-Jan')
ax1.set_ylabel('Deaths')

differences.plot(label='difference', legend= False, ax=ax2, style='k--')
ax2.set_ylabel('Difference')

plt.savefig('aug_nov_diffs.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Theres some clear periodicity going on here, so I resampled the data as weekly aggregates. This created a smoother curve:

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True, dpi=100, figsize=(10,4), gridspec_kw={'height_ratios': [3, 1]})
plt.subplots_adjust(hspace=0.02)

minimums.resample('W').sum().plot(label='count as first reported', legend=True, ax=ax1)
maximums.resample('W').sum().plot(label='count as of 28 November', legend=True, ax=ax1)
ax1.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title(f'Weekly minimum and maximum reported death counts from 23-Aug to 15-Jan')
ax1.set_ylabel('Deaths')

differences.resample('W').sum().plot(label='difference', legend= False, ax=ax2, style='k--')
ax2.set_ylabel('Difference')

plt.show()

# %% [markdown]
# ## How quickly do the counts approach their 'true' value?

# %% [markdown]
# Just from eyeballing the charts, it looks like the numbers for the last 3-7 days are likely to increase significantly over the next few releases. My next task is to get a more quantitative sense of how long that might take and how much those counts might increase, based off the past data.

# %%
# First drop the last few days to remove data that is most incomplete

df = df[df.columns[:-5]]

# %% [markdown]
# Which is the more reliable approximation of the final count: the first quartile, median, or mean?

# %%
(((df.quantile(0.25)).astype(int)/(df.max()))*100).describe().round(2)
# Out:
# count    152.00
# mean      94.13
# std        7.69
# min       50.00
# 25%       88.64
# 50%       98.11
# 75%       99.17
# max      100.00
# dtype: float64

# %%
(((df.quantile(0.5)).astype(int)/(df.max()))*100).describe().round(2)
# Out:
# count    152.00
# mean      97.18
# std        5.38
# min       50.00
# 25%       97.04
# 50%       99.07
# 75%      100.00
# max      100.00
# dtype: float64

# %%
((df.mean()/(df.max()))*100).describe().round(2)
# Out:
# count    152.00
# mean      93.25
# std        6.16
# min       52.72
# 25%       90.53
# 50%       95.84
# 75%       96.98
# max       99.23
# dtype: float64

# %% [markdown]
# To me, it looks like the median provides the best approximation. For 75% of the data, it represents at least 95% of the final count, with a S.D. spread of 6(%).
#
# Proceeding with the median as my approximator, I first identified the date of the first release reporting a death count at or above the median for each date of death.
#
# *On reflection, it may have been better to use the mean. For dates of death more than a few weeks in the past, the count reported in a lot of the releases will just be repeats of the final figure. This introduces a skew that has less of an effect on the mean than the median.*

# %%
release_date_of_median = df.apply(lambda col : col[col >= col.median()].first_valid_index())
release_date_of_median
# Out:
# 2020-08-23   2020-09-12
# 2020-08-24   2020-08-26
# 2020-08-25   2020-09-04
# 2020-08-26   2020-08-31
# 2020-08-27   2020-09-11
#                 ...
# 2021-01-17   2021-01-23
# 2021-01-18   2021-01-23
# 2021-01-19   2021-01-24
# 2021-01-20   2021-01-24
# 2021-01-21   2021-01-25
# Length: 152, dtype: datetime64[ns]

# %% [markdown]
# Taking advantage of the fact that the index is the date of death, I can easily calculate how long it takes for updates to reach the median for each date of death.

# %%
delay_to_median = release_date_of_median - release_date_of_median.index

# %%
delay_to_median.describe()
# Out:
# count                           152
# mean     15 days 05:03:09.473684210
# std       7 days 17:52:30.430939270
# min                 2 days 00:00:00
# 25%                11 days 00:00:00
# 50%                14 days 00:00:00
# 75%                19 days 00:00:00
# max                48 days 00:00:00
# dtype: object

# %% [markdown]
# Therefore, using the median as an approximation of the final value, it looks like it takes 11-12 days on average for the reported count of deaths to be within 5-10% of the final value (minimum 2 days, maximum 26 days).
#
# Which date took the longest to reach this approximation?

# %%
delay_to_median.idxmax()
# Out:
# Timestamp('2020-10-07 00:00:00')

# %%
plt.figure(figsize=(10,4), dpi=100)
df['2020-10-07'].dropna()[:20].plot(
    title='Deaths occurring on 07 October 2020, as reported in consecutive releases', 
    ylabel='Reported count', 
    xlabel='Release date', 
    marker='o', markersize=3)

plt.show()

# %% [markdown]
# Updated reports appear to trickle in much more slowly in the 10-14 days after the second release.
#
# Something interesting to note here is the apparent fluctuation, where some releases report a lower death count than the previous release. I assume this is the result of some error correction process, correcting overestimates and miscounts, but I don't know for sure.

# %% [markdown]
# ## Accuracy of count 'x' days after first report

# %% [markdown]
# The UK government considers the most recent 5 days of data to be incomplete. Based on the data from 23 Aug to 23 Nov, how closely do the reported counts after 5 days approximate the final figures?

# %%
d_later = 5
time_lag = pd.Timedelta(days=d_later)
drop_label = pd.Timestamp('2020-10-07') - time_lag #<-- dealing with the pesky missing release from 07-10-2020

lag_df = df[df.columns[:-d_later]].drop(drop_label, axis=1)
lag_lambda = lambda col : col.loc[col.name + time_lag]

lag_counts = lag_df.apply(lag_lambda)

counts_max = lag_df.max()

((lag_counts / counts_max)*100).describe().round(1)
# Out:
# count    146.0
# mean      83.2
# std        8.2
# min       40.0
# 25%       79.9
# 50%       84.7
# 75%       88.4
# max      100.0
# dtype: float64

# %% [markdown]
# On average, the reported counts account for about 84% of the final counts; at the extreme minimum accounting for 40%.

# %%
((lag_counts / counts_max)*100).tail(20)
# Out:
# 2020-12-28    79.421769
# 2020-12-29    84.509466
# 2020-12-30    75.806452
# 2020-12-31    68.633540
# 2021-01-01    66.614173
# 2021-01-02    75.301205
# 2021-01-03    84.006211
# 2021-01-04    90.482574
# 2021-01-05    83.536585
# 2021-01-06    84.718826
# 2021-01-07    82.057143
# 2021-01-08    79.725086
# 2021-01-09    84.388646
# 2021-01-10    84.816754
# 2021-01-11    91.641791
# 2021-01-12    86.466165
# 2021-01-13    83.679245
# 2021-01-14    84.885932
# 2021-01-15    82.397004
# 2021-01-16    84.670232
# dtype: float64

# %%
df['2020-11-15'].dropna().head(20)
# Out:
# Release Date
# 2020-11-16     48
# 2020-11-17    240
# 2020-11-18    281
# 2020-11-19    309
# 2020-11-20    325
# 2020-11-21    332
# 2020-11-22    340
# 2020-11-23    340
# 2020-11-24    349
# 2020-11-25    359
# 2020-11-26    358
# 2020-11-27    376
# 2020-11-28    374
# 2020-11-29    374
# 2020-11-30    374
# 2020-12-01    377
# 2020-12-02    378
# 2020-12-03    378
# 2020-12-04    379
# 2020-12-05    379
# Name: 2020-11-15 00:00:00, dtype: Int64

# %%
df['2020-08-29'].dropna().iloc[:20].plot()
# Out:
# <AxesSubplot:xlabel='Release Date'>

# %%
plt.figure(figsize=(10,4), dpi=100)
df['2020-08-29'].dropna().plot(
    title='Deaths occurring on 29 August 2020, as reported in consecutive releases', 
    ylabel='Reported count', 
    xlabel='Release date')

plt.show()

# %% [markdown]
# The fluctuation from one release to the next is even more pronounced for this date of death (and the others nearby). This is partly explained by the low overall numbers, but it does at least appear to be a more frequent oscillation, and the count isn't going up which suggests it's not an overestimation error. Curious…
#
# To visualise how accuracy increases as more time elapses, I can plot the following graph:

# %%
lag_mma = []

for d_later in range(1,21):
    
    time_lag = pd.Timedelta(days=d_later)
    drop_label = pd.Timestamp('2020-10-07') - time_lag #<-- dealing with the pesky missing release from 07-10-2020

    lag_df = df[df.columns[:-d_later]].drop(drop_label, axis=1)
    lag_lambda = lambda col : col.loc[col.name + time_lag]

    lag_counts = lag_df.apply(lag_lambda)

    counts_max = lag_df.max()
    
    lag_min = ((lag_counts / counts_max)*100).quantile(0.25)
    lag_max = ((lag_counts / counts_max)*100).quantile(0.75)
    lag_med = ((lag_counts / counts_max)*100).median()
    lag_av = ((lag_counts / counts_max)*100).mean()
    
    lag_mma.append([d_later,lag_min,lag_med,lag_max,lag_av])

# %%
all_lag = pd.DataFrame(lag_mma).set_index(0)

# %%
plt.figure(figsize=(10,4), dpi=100)
plt.plot(all_lag)
plt.xticks(range(0,21,2), range(0,21,2))
plt.title('Approximation accuracy at increasing time intervals from first release')
plt.xlabel('Days after deaths occurred')
plt.ylabel('% of final figure')
plt.legend(['1st Quartile', 'Median','3rd quartile', 'Mean'])
plt.grid()
plt.show()

# %% [markdown]
# # Alternative visualisations

# %%
import seaborn as sns

# %% [markdown]
# ### Meteors
# A way of visualising all of the data at once

# %%
strp_plot_df = df.melt(ignore_index=False).dropna().set_axis(['Date of death','Reported deaths'], axis=1)
strp_plot_df['Date of death'] = strp_plot_df['Date of death'].copy().apply(pd.Timestamp)
strp_plot_df['Delay'] = (strp_plot_df.index - strp_plot_df['Date of death']).apply(lambda d : d.days)
strp_plot_df = strp_plot_df[strp_plot_df['Delay']<=14]
strp_plot_df['Delay'] = strp_plot_df['Delay'].apply(lambda d : '7+' if d >= 7 else str(d))

strp_plot_df.info()
strp_plot_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2077 entries, 2020-08-24 to 2021-01-27
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date of death    2077 non-null   datetime64[ns]
#  1   Reported deaths  2077 non-null   object
#  2   Delay            2077 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 64.9+ KB
#              Date of death Reported deaths Delay
# Release Date
# 2020-08-24      2020-08-23               2     1
# 2020-08-25      2020-08-23               8     2
# 2020-08-26      2020-08-23              10     3
# 2020-08-27      2020-08-23              10     4
# 2020-08-28      2020-08-23              10     5

# %%
strp_plot_df.sort_values('Delay')
# Out:
#              Date of death Reported deaths Delay
# Release Date
# 2021-01-14      2021-01-14               1     0
# 2020-12-20      2020-12-20               2     0
# 2020-10-04      2020-10-04               1     0
# 2020-09-10      2020-09-10               0     0
# 2020-09-26      2020-09-26               0     0
# ...                    ...             ...   ...
# 2020-10-10      2020-10-03              45    7+
# 2020-10-11      2020-10-03              47    7+
# 2020-10-12      2020-10-03              47    7+
# 2020-10-14      2020-10-03              48    7+
# 2020-12-14      2020-12-06             304    7+
#
# [2077 rows x 3 columns]

# %%
plt.figure(dpi=100, figsize=(10,4))
sns.stripplot(x='Date of death', y='Reported deaths', data=strp_plot_df, 
              hue='Delay', 
              hue_order=[str(n) for n in range(1,7)] + ['7+'], 
              size=4,
              lw=2,
              jitter=0,
              alpha=0.75)

xtick, xlabel = plt.xticks()
plt.xticks(xtick[::5], [pd.Timestamp(t.get_text()).strftime('%b-%d') for t in xlabel[::5]],rotation=45)

plt.title('Changes in the reported count, coloured by days since deaths occurred')

plt.savefig('meteors.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# - Each **dot** represents the count for one date of death as reported in **a single release.**<br/>
# - Each **vertical line of dots** represents all counts for one date of death as reported in **consecutive releases.**<br/>
# - Points form coloured strata to preserve a sense of how the reported counts increase over time.

# %% [markdown]
# Without specifying hue, seaborn applies a colour gradient along the x-axis:

# %%
plt.figure(dpi=100, figsize=(10,4))
sns.stripplot(x='Date of death', y='Reported deaths', data=strp_plot_df, 
              size=4,
              lw=2,
              jitter=0,
              alpha=0.75)

xtick, xlabel = plt.xticks()
plt.xticks(xtick[::5], [pd.Timestamp(t.get_text()).strftime('%b-%d') for t in xlabel[::5]],rotation=45)

plt.title('Changes in the reported count')

plt.savefig('meteors_nohue.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Dropped straws

# %%
plt.figure(figsize=(10,4), dpi=100)

for col in df.columns[-10:]:
    df[col].dropna().plot()
    
plt.ylabel('Reported deaths')
plt.title('Change in reported deaths with subsequent data releases')

plt.legend([d.strftime('%d-%b') for d in df.columns[-10:]], title='Dates of Death', loc='center left', bbox_to_anchor=(1.01,0.5))

# %%
plt.figure(figsize=(10,4),dpi=100)

for r in strp_plot_df.index:
    df.loc[r].dropna()[65:].plot(label=str(r))
    
plt.title('Reported counts for all dates of death, per release')
plt.ylabel('Reported count')
plt.xlabel('Date of Death')

ticks, labels = plt.xticks()
labels = ['Oct-29', 'Nov-01', 'Nov-05', 'Nov-09', 'Nov-13', 'Nov-17']
plt.xticks(ticks, labels)

plt.legend([d.strftime('%d-%b') for d in df.index], 
           title='Release', 
           loc='upper center', 
           bbox_to_anchor=(0.5,-0.3), 
           ncol=10)
plt.show()

# %% [markdown]
# ## Ideas for further work
# - Create an interactive dashboard allowing users to investigate the relationship between delay since first reporting and accuracy
# - Create a machine learning model to predict what the final death count will be at time = 0
